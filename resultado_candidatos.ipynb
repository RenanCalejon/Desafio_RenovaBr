# %% [markdown]
# #Tratamento de dados do resultado dos candidatos
# - Por se tratar de um grande dataset que utrapassa 2GB que é o maximo de tamanho que o colab suporta , foram feita os remoção das colunas desnecessárias no Excel
# - Importanção de pandas para a análise e manipulação de dados em Python.
# - Comando para lê um arquivo CSV
# - Exibição das as cinco primeiras linhas do DataFrame

# %%
import pandas as pd
df = pd.read_csv("/home/SP_turno_1_v1.csv", sep=';', encoding="ISO-8859-1")
df.head(5)
# Out:
#    ANO_ELEICAO SG_UF NM_MUNICIPIO DS_CARGO_PERGUNTA  NR_PARTIDO SG_PARTIDO  \
# 0         2020    SP    SÃO PAULO          Prefeito          -1     #NULO#
# 1         2020    SP    SÃO PAULO          Prefeito          13         PT
# 2         2020    SP    SÃO PAULO          Prefeito          18       REDE
# 3         2020    SP    SÃO PAULO          Prefeito          40        PSB
# 4         2020    SP    SÃO PAULO          Prefeito          45       PSDB
#
#                                 NM_PARTIDO     NM_VOTAVEL  QT_VOTOS
# 0                                   #NULO#         Branco       5.0
# 1                Partido dos Trabalhadores   JILMAR TATTO       4.0
# 2                    Rede Sustentabilidade   MARINA HELOU       1.0
# 3            Partido Socialista Brasileiro  MÁRCIO FRANÇA      29.0
# 4  Partido da Social Democracia Brasileira    BRUNO COVAS     111.0

# %% [markdown]
# # Exibição das colunas restantes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69190 entries, 0 to 69189
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO_ELEICAO        69190 non-null  int64
#  1   SG_UF              69190 non-null  object
#  2   NM_MUNICIPIO       69190 non-null  object
#  3   DS_CARGO_PERGUNTA  69190 non-null  object
#  4   NR_PARTIDO         69190 non-null  int64
#  5   SG_PARTIDO         69190 non-null  object
#  6   NM_PARTIDO         69190 non-null  object
#  7   NM_VOTAVEL         69189 non-null  object
#  8   QT_VOTOS           69189 non-null  float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 4.8+ MB

# %% [markdown]
# # Removendo registros nulos e em branco

# %%
df = df[(df != '#NULO#').all(axis=1) & (df != -1).all(axis=1)]

# %%
df.head(10)
# Out:
#     ANO_ELEICAO SG_UF NM_MUNICIPIO DS_CARGO_PERGUNTA  NR_PARTIDO  \
# 1          2020    SP    SÃO PAULO          Prefeito          13
# 2          2020    SP    SÃO PAULO          Prefeito          18
# 3          2020    SP    SÃO PAULO          Prefeito          40
# 4          2020    SP    SÃO PAULO          Prefeito          45
# 5          2020    SP    SÃO PAULO          Prefeito          17
# 6          2020    SP    SÃO PAULO          Prefeito          51
# 8          2020    SP    SÃO PAULO          Prefeito          10
# 9          2020    SP    SÃO PAULO          Prefeito          50
# 10         2020    SP    SÃO PAULO          Prefeito          55
# 11         2020    SP    SÃO PAULO          Vereador          18
#
#       SG_PARTIDO                               NM_PARTIDO  \
# 1             PT                Partido dos Trabalhadores
# 2           REDE                    Rede Sustentabilidade
# 3            PSB            Partido Socialista Brasileiro
# 4           PSDB  Partido da Social Democracia Brasileira
# 5            PSL                   Partido Social Liberal
# 6       PATRIOTA                                 Patriota
# 8   REPUBLICANOS                             REPUBLICANOS
# 9           PSOL           Partido Socialismo e Liberdade
# 10           PSD               Partido Social Democrático
# 11          REDE                    Rede Sustentabilidade
#
#                    NM_VOTAVEL  QT_VOTOS
# 1                JILMAR TATTO       4.0
# 2                MARINA HELOU       1.0
# 3               MÁRCIO FRANÇA      29.0
# 4                 BRUNO COVAS     111.0
# 5            JOICE HASSELMANN       2.0
# 6   ARTHUR DO VAL MAMÃE FALEI      10.0
# 8            CELSO RUSSOMANNO      18.0
# 9            GUILHERME BOULOS      43.0
# 10           ANDREA MATARAZZO       8.0
# 11             RAQUEL MARQUES       1.0

# %% [markdown]
# # Exportando os dados tratados para um arquivo csv no meu google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
df.to_csv('/content/drive/My Drive/seu_arquivo.csv', index=False)
# Out:
# Mounted at /content/drive
